# %%
import os
import mokapot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append("..")
sys.path
import data_loader as dl

# %% [markdown]
# Used to clean the data for the best and worst data graphs. Drops decoys and duplicate scans.

# %%
def filter_data(df, prob_column):
     #drop decoys
    df = df[df["decoy"]== 'False']
    #sort by qvalue
    df = df.sort_values(prob_column)
    #Drop duplicates
    df = df.drop_duplicates(subset=["scan"], keep="first") #keep highest scoring

    return df

# %% [markdown]
# Used to clean data for the decoy graph. Pulls out decoys and drops duplicate scans.

# %%
def filter_decoy_data(df, prob_column):
     #drop decoys
    df = df[df["decoy"]== 'True']
    #Drop duplicates
    df = df.drop_duplicates(subset=["scan"], keep="first") #keep highest scoring

    return df

# %%
def get_data(before_df):

    data = pd.read_csv(before_df, sep = "\t")    
    data = filter_data(data, "QValue")
    
    return data

# %%
def get_decoy_data(before_df):

    data = pd.read_csv(before_df, sep = "\t")     
    data = filter_decoy_data(data, "QValue")
    
    return data

# %% [markdown]
# Getting the data for the best data graph. Clean all the data, pull out the data that has a QValue of 0.0 and make the graph.

# %%
best_data = get_data("test.tsv")

#take only scans with 0 Qvalue
best_data = best_data[best_data["QValue"]== 0.0]
best_data = best_data.head(300)
best_data
# Out:
# /Users/daishavanderwatt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3263: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
#       Unnamed: 0                            File Name   scan         y  \
# 0              0  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib  16668  52.52059
# 4224        4224  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib  11505  40.21101
# 4223        4223  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib   6188  27.61035
# 4222        4222  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib  26968  77.17926
# 4221        4221  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib  12997  43.77077
# ...          ...                                  ...    ...       ...
# 4121        4121  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib  23704  69.34007
# 4120        4120  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib  14791  48.04092
# 4119        4119  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib  16310  51.67092
# 4118        4118  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib  21153  63.23001
# 4127        4127  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib  19243  58.66267
#
#       Num Experimental Peaks  Total Ion Current  Precursor Scan Number  \
# 0                      101.0       335251.91071                  16649
# 4224                    93.0       280621.26892                  11487
# 4223                    70.0       135619.72083                   6170
# 4222                    74.0       177492.46899                  26948
# 4221                    82.0       202263.41882                  12984
# ...                      ...                ...                    ...
# 4121                    65.0       156625.87585                  23691
# 4120                    82.0       249153.65375                  14779
# 4119                    84.0       175718.28577                  16297
# 4118                    97.0       215562.20636                  21138
# 4127                   120.0       271462.01520                  19224
#
#       Precursor Charge  Precursor MZ  Precursor Mass  ...  QValue  \
# 0                  2.0    1280.62814      2559.24172  ...     0.0
# 4224               3.0     496.24615      1485.71662  ...     0.0
# 4223               2.0     505.76641      1009.51826  ...     0.0
# 4222               2.0     786.88324      1571.75192  ...     0.0
# 4221               3.0     577.27851      1728.81370  ...     0.0
# ...                ...           ...             ...  ...     ...
# 4121               3.0     555.94774      1664.82138  ...     0.0
# 4120               2.0     642.87939      1283.74422  ...     0.0
# 4119               3.0     611.29374      1830.85941  ...     0.0
# 4118               3.0     646.35233      1936.03515  ...     0.0
# 4127               2.0     645.81935      1289.62415  ...     0.0
#
#       Cumulative Target Notch Cumulative Decoy Notch QValue Notch       PEP  \
# 0                           6                    0.0          0.0  0.000024
# 4224                    33891                    0.0          0.0  0.000015
# 4223                    33886                    0.0          0.0  0.000025
# 4222                    33866                    0.0          0.0  0.000469
# 4221                    33851                    0.0          0.0  0.000071
# ...                       ...                    ...          ...       ...
# 4121                    32994                    0.0          0.0  0.000082
# 4120                    32986                    0.0          0.0  0.000139
# 4119                    32970                    0.0          0.0  0.000079
# 4118                    32964                    0.0          0.0  0.000029
# 4127                    33034                    0.0          0.0  0.000231
#
#      PEP_QValue                                       temp_peptide  \
# 0      0.000010                          LVQDVANNTNEEAGDGTTTATVLAR
# 4224   0.000006    RDPHLAC[Common Fixed:Carbamidomethyl on C]VAYER
# 4223   0.000011                                          VEQHVVDGK
# 4222   0.000089                                     FGFPEGSVELYAEK
# 4221   0.000025  NVTDVVNTC[Common Fixed:Carbamidomethyl on C]HD...
# ...         ...                                                ...
# 4121   0.000028                                     YEDFSNLGTTHLLR
# 4120   0.000040                                      LASVPGSQTVVVK
# 4119   0.000027                            IM+15.995DPNIVGSEHYDVAR
# 4118   0.000012                                  ALPAVQQNNLDEDLIRK
# 4127   0.000056                                       FDGILTEGEGPR
#
#                         peptide                          x     y_pred
# 0     LVQDVANNTNEEAGDGTTTATVLAR  LVQDVANNTNEEAGDGTTTATVLAR  47.859550
# 4224               RDPHLACVAYER              RDPHLAC2VAYER  40.001198
# 4223                  VEQHVVDGK                  VEQHVVDGK  32.592903
# 4222             FGFPEGSVELYAEK             FGFPEGSVELYAEK  77.139150
# 4221           NVTDVVNTCHDAGISK          NVTDVVNTC2HDAGISK  41.467903
# ...                         ...                        ...        ...
# 4121             YEDFSNLGTTHLLR             YEDFSNLGTTHLLR  73.573080
# 4120              LASVPGSQTVVVK              LASVPGSQTVVVK  47.539000
# 4119    IM+15.995DPNIVGSEHYDVAR          IM1DPNIVGSEHYDVAR  54.669300
# 4118          ALPAVQQNNLDEDLIRK          ALPAVQQNNLDEDLIRK  74.072310
# 4127               FDGILTEGEGPR               FDGILTEGEGPR  59.157257
#
# [300 rows x 60 columns]

# %% [markdown]
# Graph representing some of the best scored scans

# %%
plt.scatter(best_data['y_pred'], best_data['y'])
plt.ylabel("Predicted retention time")
plt.xlabel("Actual retention time")
plt.title("Actual versus predicted retention time for ideal data")
plt.show()

# %% [markdown]
# Formatting and cleaning the data for the graph representing some of the worst scoring data

# %%
worst_data = get_data("test.tsv")
worst_data = worst_data.tail(300)
# Out:
# /Users/daishavanderwatt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3263: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
plt.scatter(worst_data['y_pred'], worst_data['y'])
plt.ylabel("Predicted retention time")
plt.xlabel("Actual retention time")
plt.title("Actual versus predicted retention time for worst data")
plt.show()

# %% [markdown]
# Graph representing decoy data

# %%
decoy_data = get_decoy_data("test.tsv")
decoy_data = decoy_data.head(300)
decoy_data
# Out:
#        Unnamed: 0                            File Name   scan         y  \
# 8138         8138  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib  13373  44.66281
# 9271         9271  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib  14448  47.22267
# 9921         9921  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib  11675  40.61797
# 10090       10090  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib   9486  35.42470
# 10094       10094  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib   6446  28.22268
# ...           ...                                  ...    ...       ...
# 16569       16569  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib  16725  52.65596
# 16571       16571  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib   8086  32.10110
# 16575       16575  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib  16452  52.00810
# 16578       16578  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib   9612  35.72404
# 16584       16584  Ex_Auto_J3_30umTB_2ngQC_60m_1-calib  11105  39.25691
#
#        Num Experimental Peaks  Total Ion Current  Precursor Scan Number  \
# 8138                    200.0       3.754640e+06                  13359
# 9271                     60.0       1.894570e+05                  14427
# 9921                     96.0       4.089807e+05                  11663
# 10090                   102.0       3.102589e+05                   9467
# 10094                    88.0       6.465188e+05                   6434
# ...                       ...                ...                    ...
# 16569                   146.0       3.124429e+05                  16704
# 16571                   109.0       4.576445e+05                   8069
# 16575                   112.0       2.418065e+05                  16440
# 16578                   116.0       6.246679e+05                   9600
# 16584                   197.0       9.709415e+05                  11091
#
#        Precursor Charge  Precursor MZ  Precursor Mass  ...    QValue  \
# 8138                2.0     458.25823       914.50191  ...  0.000458
# 9271                2.0     406.75289       811.49124  ...  0.000826
# 9921                2.0     478.77489       955.53523  ...  0.000896
# 10090               2.0     501.28464      1000.55473  ...  0.000983
# 10094               2.0     601.32415      1200.63374  ...  0.000997
# ...                 ...           ...             ...  ...       ...
# 16569               2.0     517.79105      1033.56754  ...  0.027979
# 16571               2.0     514.79042      1027.56629  ...  0.028065
# 16575               2.0     700.85438      1399.69421  ...  0.028111
# 16578               2.0     397.71083       793.40710  ...  0.028158
# 16584               2.0     532.29946      1062.58437  ...  0.028333
#
#        Cumulative Target Notch Cumulative Decoy Notch QValue Notch       PEP  \
# 8138                     56753                   27.0     0.000462  0.404217
# 9271                     64652                   52.0     0.000803  0.004314
# 9921                     67261                   59.0     0.000875  0.072843
# 10090                    68003                   65.5     0.000963  0.099350
# 10094                    68013                   66.5     0.000977  0.585276
# ...                        ...                    ...          ...       ...
# 16569                     1999                  627.0     0.313657  0.999951
# 16571                   101026                 2259.7     0.022367  0.999467
# 16575                     2004                  633.0     0.315868  0.988252
# 16578                   101041                 2265.7     0.022423  0.994938
# 16584                   101086                 2276.2     0.022517  0.979697
#
#       PEP_QValue   temp_peptide        peptide              x     y_pred
# 8138    0.011020       VEQDILAK       VEQDILAK       VEQDILAK  48.418293
# 9271    0.000426       PLLGAVSR       PLLGAVSR       PLLGAVSR  47.540840
# 9921    0.002575      PIGQSIDVK      PIGQSIDVK      PIGQSIDVK  44.054314
# 10090   0.003182      KAQGELLDK      KAQGELLDK      KAQGELLDK  43.875000
# 10094   0.018169    LKGALQEAEDK    LKGALQEAEDK    LKGALQEAEDK  38.958057
# ...          ...            ...            ...            ...        ...
# 16569   0.266363       KEKMEQLK       KEKMEQLK       KEKMEQLK  36.677277
# 16571   0.189646      KEGKNDLPK      KEGKNDLPK      KEGKNDLPK  32.083510
# 16575   0.098266  ENVVEGTENLPAK  ENVVEGTENLPAK  ENVVEGTENLPAK  45.273216
# 16578   0.120262       SGFLGGTR       SGFLGGTR       SGFLGGTR  47.308280
# 16584   0.084714      INLVEPHNK      INLVEPHNK      INLVEPHNK  39.937073
#
# [300 rows x 60 columns]

# %%
plt.scatter(decoy_data['y_pred'], decoy_data['y'])
plt.ylabel("Predicted retention time")
plt.xlabel("Actual retention time")
plt.title("Actual versus predicted retention time for decoy data")
plt.show()
