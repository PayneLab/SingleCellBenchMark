# %% [markdown]
# The purpose of this notebook is to test whether adding addition features of the number of max consecutive y peaks and "perc_in_ladder"(need to say better) helps MokaPot to score more PSMs at or below a certain cuttoff.

# %%
import os
import mokapot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append("..")
sys.path
import data_loader as dl
import scipy.stats as stats

# %% [markdown]
# The purpose of this function is to clean up the original 'before' data so that we are not counting decoys or duplicate scans.

# %%
def filter_data(df, prob_column):
     #drop decoys
    df = df[df["decoy"]== False]
    #sort by qvalue
    df = df.sort_values(prob_column)
    #Drop duplicates
    df = df.drop_duplicates(subset=["scan"], keep="first") #keep highest scoring

    return df

# %% [markdown]
# This gives us the before data. It will not be run through MokaPot. It's purpose is to give us the ability to count how many PSMs originally are at or under a specific cutoff and compare that to the number we get after we run the data through MokaPot.

# %%
def get_PreMokaPot_data(file):
    data = dl.clean_metamorph(file)
    data = filter_data(data,'QValue')
    return data

# %% [markdown]
# This reads in and cleans the data that will be run through MokaPot. MetaMorphues has a special output file that is formatted to be able to run through MokaPot.

# %%
def get_data_for_MokaPot(file):
    df_2 = dl.get_pin_file(file)
    df_2 = df_2.iloc[1: :]
    df_2 = df_2.drop_duplicates(subset=["ScanNr"], keep="first")
    
    return df_2

# %%
def calculate_diff(row):
    num = row['y'] - row['y_pred']
    if num < 0:
        num = num * (-1)
    return num

# %% [markdown]
# MetaMorpheus gives an output file that is specifically formatted for MokaPot. However, this file does not have q values, which we need to compare the before and after data. However, once the decoys are dropped from both files, the regular before file and the specailly formatted file contain the same scan numbers.
# The before file is used to compute the number of max consecutive y peaks and "perc_in_ladder". These columns are then taken and then added to the specially formatted file.
#
# Here we read in the speically formatted file and the file that has the additional feature columns in it. Decoys are dropped from both of them, giving us the same number of scans in both file. We splice out the scan, max_consecutive_y, and "perc_in_ladder" columns. These columns are then joined with the formatted file based on their scan numbers. We can use this file to run through MokaPot and compare if the extra feature columns help MokaPot to score more PSMs below our cutoff.

# %%
def get_peaks_data(file):

    data = pd.read_csv("peaks_files/" + file + "_peaks_data.csv")
    
    #Change the ladder column tye to float 
    data = data.astype({"perc_in_ladder": float})
    
    #sort based on the probability column
    data = data.sort_values('QValue')
    #drop duplicate scans
    data = data.drop_duplicates(subset=["scan"], keep="first") #keep highest scoring
    
    data = data.rename(columns = {"scan": "ScanNr"})
    data = data.filter(['ScanNr', 'max_consecutive_y', 'max_consecutive_b', 'perc_in_ladder'])
    data = data.set_index("ScanNr")
    
    #setting up the data from the pin file
    df_2 = dl.get_pin_file(file)
    df_2 = df_2.iloc[1: :]
    df_2 = df_2.astype({"ScanNr": int})
    df_2 = df_2.drop_duplicates(subset=["ScanNr"], keep="first")
    df_2 = df_2.set_index("ScanNr")
    
    
    joined_df = df_2.join(data, how = "outer")
    joined_df.reset_index(inplace=True)
    
    return joined_df

# %% [markdown]
# Here we read in the speically formatted file and the file that has the additional feature columns in it. Decoys are dropped from both of them, giving us the same number of scans in both file. We splice out the scan, and difference columns. These columns are then joined with the formatted file based on their scan numbers. We can use this file to run through MokaPot and compare if the extra feature columns help MokaPot to score more PSMs below our cutoff.

# %%
#Retriving and formatting the df that has the retention time info in it. Also doing the math to get 
#the difference colum

def retrive_RT_df(file):
    
    file_path = "predicted_data/" + file + "_predicted/test.tsv"
    
    data = pd.read_csv(file_path, sep = "\t")    
    
    #sort based on the probability column
    data = data.sort_values('QValue')
    #drop duplicate scans
    data = data.drop_duplicates(subset=["scan"], keep="first") #keep highest scoring
    #changing the type
    data = data.astype({'y_pred': float})
    
    #calculating the difference column
    data['difference'] = data.apply(calculate_diff, axis = 1)
    
    data = data.rename(columns = {"scan": "ScanNr"})
    data = data.filter(['ScanNr', 'difference'])
    data = data.set_index("ScanNr")
    return data

# %%
def get_retentionTime_data(file):

    data = retrive_RT_df(file)
    
    #setting up the data from the pin file
    df_2 = dl.get_pin_file(file)
    df_2 = df_2.iloc[1: :]
    df_2 = df_2.astype({"ScanNr": int})
    df_2 = df_2.drop_duplicates(subset=["ScanNr"], keep="first")
    df_2 = df_2.set_index("ScanNr")
    
    
    joined_df = df_2.join(data, how = "outer")
    joined_df.reset_index(inplace=True)
    
    return joined_df

# %% [markdown]
# Taking the dataframe that has the peaks features added on and joining the additional retention time differnce column onto it. Returning the joined dataframe

# %%
def get_all_features_data(peaksData, RTdata):
    RTdata = RTdata.filter(['ScanNr', 'difference'])
    RTdata = RTdata.set_index("ScanNr")
    RTdata = RTdata.astype({'difference': float})
    
    peaksData = peaksData.set_index("ScanNr")
    peaksData = peaksData.astype({'perc_in_ladder': float})
    
    joined_df = peaksData.join(RTdata, how = "outer")
    joined_df.reset_index(inplace=True)
    
    return joined_df

# %% [markdown]
# This is code that was taken directly from the MokaPot program. It formats the data for the graphs. The purpose of the graphs is to compare the preMokaPot data to the postMokaPot data and compare if we are getting more scans at or below a certain cutoff after running data through MokaPot.

# %%
def plot_qvalues(qvalues, threshold=0.01, ax=None, **kwargs):
    if ax is None:
        ax = plt.gca()

    # Calculate cumulative targets at each q-value
    qvals = pd.Series(qvalues, name="qvalue")
    qvals = qvals.sort_values(ascending=True).to_frame()
    qvals["target"] = 1
    qvals["num"] = qvals["target"].cumsum()
    qvals = qvals.groupby(["qvalue"]).max().reset_index()
    qvals = qvals[["qvalue", "num"]]

    zero = pd.DataFrame({"qvalue": qvals["qvalue"][0], "num": 0}, index=[-1])
    qvals = pd.concat([zero, qvals], sort=True).reset_index(drop=True)

    xmargin = threshold * 0.05
    ymax = qvals.num[qvals["qvalue"] <= (threshold + xmargin)].max()
    ymargin = ymax * 0.05

    # Set margins
    curr_ylims = ax.get_ylim()
    if curr_ylims[1] < ymax + ymargin:
        ax.set_ylim(0 - ymargin, ymax + ymargin)

    ax.set_xlim(0 - xmargin, threshold + xmargin)
    ax.set_xlabel("q-value")
    ax.set_ylabel(f"Discoveries")

    ax.step(qvals["qvalue"].values, qvals.num.values, where="post", **kwargs)

    return ax

# %%
def plot_qvalues(qvalues, threshold=0.01, ax=None, **kwargs):
    if ax is None:
        ax = plt.gca()

    # Calculate cumulative targets at each q-value
    qvals = pd.Series(qvalues, name="qvalue")
    qvals = qvals.sort_values(ascending=True).to_frame()
    qvals["target"] = 1
    qvals["num"] = qvals["target"].cumsum()
    qvals = qvals.groupby(["qvalue"]).max().reset_index()
    qvals = qvals[["qvalue", "num"]]

    zero = pd.DataFrame({"qvalue": qvals["qvalue"][0], "num": 0}, index=[-1])
    qvals = pd.concat([zero, qvals], sort=True).reset_index(drop=True)

    xmargin = threshold * 0.05
    ymax = qvals.num[qvals["qvalue"] <= (threshold + xmargin)].max()
    ymargin = ymax * 0.05

    # Set margins
    curr_ylims = ax.get_ylim()
    if curr_ylims[1] < ymax + ymargin:
        ax.set_ylim(0 - ymargin, ymax + ymargin)

    ax.set_xlim(0 - xmargin, threshold + xmargin)
    ax.set_xlabel("q-value")
    ax.set_ylabel(f"Discoveries")

    ax.step(qvals["qvalue"].values, qvals.num.values, where="post", **kwargs)

    return ax

# %%
#Read all the files into a list here
file_names = ["2ng_rep1", "2ng_rep2", "2ng_rep3", "2ng_rep4", "2ng_rep5", "2ng_rep6", 
              "0.2ng_rep1", "0.2ng_rep2", "0.2ng_rep3", "0.2ng_rep4", "0.2ng_rep5", "0.2ng_rep6"]

# %% [markdown]
# In order to tell if the new added features are helping MokaPot to score the PSMs higher, we run the program a certain number of times and look at the average scores.
# We read in the data for the pin file, the regular data, and the data that has the added features. Because MokaPot gives an output file that is already formatted for MokaPot, we have to splice out the extra columns and joing them with the pin file.

# %%
limit = 25
file_number = 0
all_results = pd.DataFrame()


for file in file_names:
    file_number +=1
    rounds = 0
    print("running " + file)
    
    no_addedFeats_list = []
    #peaks_feature_list = []
    #RT_feature_list = []
    all_features_list = []
    
    #original_MM = get_PreMokaPot_data('2ng_rep1')
    regular_df = get_data_for_MokaPot(file)
    peaks_df = get_peaks_data(file)
    RT_df = get_retentionTime_data(file)
    all_feats_df = get_all_features_data(peaks_df, RT_df)


    while rounds < limit:

        #regular data, no additional features
        mm_for_MP = mokapot.read_pin(regular_df) 
        regular_results, models = mokapot.brew(mm_for_MP)

        #just the peaks features
#         mm_peaksFeat_MP = mokapot.read_pin(peaks_df) 
#         peaksAdded_results, added_models = mokapot.brew(mm_peaksFeat_MP)

        #just the retention time feature
#         mm_RT_feat_MP = mokapot.read_pin(RT_df)
#         RTadded_results, models = mokapot.brew(mm_RT_feat_MP)

        #all the additional features
        all_features_MP = mokapot.read_pin(all_feats_df)
        allAdded_results, models = mokapot.brew(all_features_MP)


        no_addedFeats_list.append(len(regular_results.psms[regular_results.psms['mokapot q-value'] <= 0.01]))
        print("without added feat: " + str(len(regular_results.psms[regular_results.psms['mokapot q-value'] <= 0.01])))

#         peaks_feature_list.append(len(peaksAdded_results.psms[peaksAdded_results.psms['mokapot q-value'] <= 0.01]))
#         print("with peaks feat: " + str(len(peaksAdded_results.psms[peaksAdded_results.psms['mokapot q-value'] <= 0.01])))

#         RT_feature_list.append(len(RTadded_results.psms[RTadded_results.psms['mokapot q-value'] <= 0.01]))
#         print("with RT feat: " + str(len(RTadded_results.psms[RTadded_results.psms['mokapot q-value'] <= 0.01])))

        all_features_list.append(len(allAdded_results.psms[allAdded_results.psms['mokapot q-value'] <= 0.01]))
        print("with all added feat: " + str(len(allAdded_results.psms[allAdded_results.psms['mokapot q-value'] <= 0.01])))

        rounds+= 1
        print("finished round " + str(rounds))
    
    #adding the new results to the df with all the PSMs found
    all_results[file + " None"] = no_addedFeats_list
    all_results[file + " All"] = all_features_list
# Out:
# running 2ng_rep1
# /Users/daishavanderwatt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3343: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# without added feat: 14676
# with all added feat: 14804
# finished round 1
# without added feat: 14619
# with all added feat: 14440
# finished round 2
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 14411
# with all added feat: 14815
# finished round 3
# without added feat: 14423
# with all added feat: 14810
# finished round 4
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 14411
# with all added feat: 14833
# finished round 5
# without added feat: 14462
# with all added feat: 14811
# finished round 6
# without added feat: 14360
# with all added feat: 14838
# finished round 7
# without added feat: 14340
# with all added feat: 14835
# finished round 8
# without added feat: 14606
# with all added feat: 14818
# finished round 9
# without added feat: 14645
# with all added feat: 14801
# finished round 10
# without added feat: 14358
# with all added feat: 14821
# finished round 11
# without added feat: 14412
# with all added feat: 14838
# finished round 12
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 14324
# with all added feat: 14836
# finished round 13
# without added feat: 14459
# with all added feat: 14809
# finished round 14
# without added feat: 14706
# with all added feat: 14801
# finished round 15
# without added feat: 14420
# with all added feat: 14824
# finished round 16
# without added feat: 14602
# with all added feat: 14847
# finished round 17
# without added feat: 14594
# with all added feat: 14804
# finished round 18
# without added feat: 14357
# with all added feat: 14856
# finished round 19
# without added feat: 14421
# with all added feat: 14481
# finished round 20
# without added feat: 14377
# with all added feat: 14823
# finished round 21
# without added feat: 14563
# with all added feat: 14506
# finished round 22
# without added feat: 14423
# with all added feat: 14850
# finished round 23
# without added feat: 14382
# with all added feat: 14534
# finished round 24
# without added feat: 14121
# with all added feat: 14799
# finished round 25
# running 2ng_rep2
# /Users/daishavanderwatt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3343: DtypeWarning: Columns (12,20,21,22,23,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# without added feat: 14186
# with all added feat: 14445
# finished round 1
# without added feat: 14158
# with all added feat: 14474
# finished round 2
# without added feat: 14329
# with all added feat: 14470
# finished round 3
# without added feat: 14390
# with all added feat: 14489
# finished round 4
# without added feat: 14343
# with all added feat: 14460
# finished round 5
# without added feat: 14366
# with all added feat: 14506
# finished round 6
# without added feat: 14368
# with all added feat: 14473
# finished round 7
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 14423
# with all added feat: 14535
# finished round 8
# without added feat: 14368
# with all added feat: 14484
# finished round 9
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 14365
# with all added feat: 14515
# finished round 10
# without added feat: 14387
# with all added feat: 14485
# finished round 11
# without added feat: 14358
# with all added feat: 14445
# finished round 12
# without added feat: 14347
# with all added feat: 14512
# finished round 13
# without added feat: 14354
# with all added feat: 14471
# finished round 14
# without added feat: 14335
# with all added feat: 14478
# finished round 15
# without added feat: 14362
# with all added feat: 14503
# finished round 16
# without added feat: 14337
# with all added feat: 14505
# finished round 17
# without added feat: 14359
# with all added feat: 14494
# finished round 18
# without added feat: 14370
# with all added feat: 14512
# finished round 19
# without added feat: 14357
# with all added feat: 14502
# finished round 20
# without added feat: 14383
# with all added feat: 14539
# finished round 21
# without added feat: 14391
# with all added feat: 14462
# finished round 22
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 14230
# with all added feat: 14486
# finished round 23
# without added feat: 14356
# with all added feat: 14427
# finished round 24
# without added feat: 14357
# with all added feat: 14509
# finished round 25
# running 2ng_rep3
# /Users/daishavanderwatt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3343: DtypeWarning: Columns (12,20,22,23,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# without added feat: 12310
# with all added feat: 12363
# finished round 1
# without added feat: 12264
# with all added feat: 12332
# finished round 2
# without added feat: 12171
# with all added feat: 12367
# finished round 3
# without added feat: 12263
# with all added feat: 12350
# finished round 4
# without added feat: 12311
# with all added feat: 12315
# finished round 5
# without added feat: 12225
# with all added feat: 12333
# finished round 6
# without added feat: 12309
# with all added feat: 12421
# finished round 7
# without added feat: 12167
# with all added feat: 12386
# finished round 8
# without added feat: 12220
# with all added feat: 12365
# finished round 9
# without added feat: 12255
# with all added feat: 12380
# finished round 10
# without added feat: 12171
# with all added feat: 12377
# finished round 11
# without added feat: 12270
# with all added feat: 12434
# finished round 12
# without added feat: 12181
# with all added feat: 12417
# finished round 13
# without added feat: 12175
# with all added feat: 12250
# finished round 14
# without added feat: 12264
# with all added feat: 12352
# finished round 15
# without added feat: 12235
# with all added feat: 12420
# finished round 16
# without added feat: 12317
# with all added feat: 12248
# finished round 17
# without added feat: 12304
# with all added feat: 12340
# finished round 18
# without added feat: 12286
# with all added feat: 12404
# finished round 19
# without added feat: 12257
# with all added feat: 12389
# finished round 20
# without added feat: 12122
# with all added feat: 12369
# finished round 21
# without added feat: 12195
# with all added feat: 12387
# finished round 22
# without added feat: 12302
# with all added feat: 12390
# finished round 23
# without added feat: 12309
# with all added feat: 12313
# finished round 24
# without added feat: 12239
# with all added feat: 12410
# finished round 25
# running 2ng_rep4
# /Users/daishavanderwatt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3343: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# without added feat: 12098
# with all added feat: 12065
# finished round 1
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 12175
# with all added feat: 12025
# finished round 2
# without added feat: 12122
# with all added feat: 11964
# finished round 3
# without added feat: 11905
# with all added feat: 12071
# finished round 4
# without added feat: 12128
# with all added feat: 12249
# finished round 5
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 12056
# with all added feat: 12166
# finished round 6
# without added feat: 11968
# with all added feat: 12043
# finished round 7
# without added feat: 12170
# with all added feat: 12227
# finished round 8
# without added feat: 12159
# with all added feat: 11932
# finished round 9
# without added feat: 11954
# with all added feat: 12022
# finished round 10
# without added feat: 12180
# with all added feat: 12222
# finished round 11
# without added feat: 12015
# with all added feat: 12112
# finished round 12
# without added feat: 12069
# with all added feat: 12038
# finished round 13
# without added feat: 12078
# with all added feat: 12087
# finished round 14
# without added feat: 11956
# with all added feat: 12069
# finished round 15
# without added feat: 12100
# with all added feat: 12059
# finished round 16
# without added feat: 12026
# with all added feat: 12207
# finished round 17
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 11847
# with all added feat: 12051
# finished round 18
# without added feat: 12009
# with all added feat: 11957
# finished round 19
# without added feat: 11843
# with all added feat: 12188
# finished round 20
# without added feat: 11902
# with all added feat: 12017
# finished round 21
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 12050
# with all added feat: 12252
# finished round 22
# without added feat: 12111
# with all added feat: 12151
# finished round 23
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 11900
# with all added feat: 12036
# finished round 24
# without added feat: 11876
# with all added feat: 11890
# finished round 25
# running 2ng_rep5
# /Users/daishavanderwatt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3343: DtypeWarning: Columns (12,20,21,22,23,24,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16772
# with all added feat: 16835
# finished round 1
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16763
# with all added feat: 16783
# finished round 2
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16761
# with all added feat: 16826
# finished round 3
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16727
# with all added feat: 16813
# finished round 4
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16748
# with all added feat: 16835
# finished round 5
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16705
# with all added feat: 16822
# finished round 6
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16722
# with all added feat: 16821
# finished round 7
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16750
# with all added feat: 16812
# finished round 8
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16757
# with all added feat: 16817
# finished round 9
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16750
# with all added feat: 16788
# finished round 10
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16780
# with all added feat: 16798
# finished round 11
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16772
# with all added feat: 16820
# finished round 12
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16742
# with all added feat: 16805
# finished round 13
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16723
# with all added feat: 16781
# finished round 14
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16804
# with all added feat: 16809
# finished round 15
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16773
# with all added feat: 16826
# finished round 16
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16748
# with all added feat: 16804
# finished round 17
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16740
# with all added feat: 16825
# finished round 18
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16711
# with all added feat: 16838
# finished round 19
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16730
# with all added feat: 16841
# finished round 20
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16755
# with all added feat: 16808
# finished round 21
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16755
# with all added feat: 16812
# finished round 22
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16695
# with all added feat: 16821
# finished round 23
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16752
# with all added feat: 16786
# finished round 24
# WARNING:mokapot.dataset:Missing values detected in the following features:
# WARNING:mokapot.dataset:  - difference
# WARNING:mokapot.dataset:Dropping features with missing values...
# without added feat: 16788
# with all added feat: 16792
# finished round 25
# running 2ng_rep6
# /Users/daishavanderwatt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3343: DtypeWarning: Columns (20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# without added feat: 15769
# with all added feat: 15906
# finished round 1
# without added feat: 15732
# with all added feat: 15901
# finished round 2
# without added feat: 15759
# with all added feat: 15925
# finished round 3
# without added feat: 15762
# with all added feat: 15915
# finished round 4
# without added feat: 15766
# with all added feat: 15934
# finished round 5
# without added feat: 15787
# with all added feat: 15927
# finished round 6
# without added feat: 15746
# with all added feat: 15914
# finished round 7
# without added feat: 15737
# with all added feat: 15927
# finished round 8
# without added feat: 15761
# with all added feat: 15920
# finished round 9
# without added feat: 15696
# with all added feat: 15920
# finished round 10
# without added feat: 15712
# with all added feat: 15934
# finished round 11
# without added feat: 15795
# with all added feat: 15911
# finished round 12
# without added feat: 15770
# with all added feat: 15882
# finished round 13
# without added feat: 15745
# with all added feat: 15900
# finished round 14
# without added feat: 15701
# with all added feat: 15894
# finished round 15
# without added feat: 15770
# with all added feat: 15897
# finished round 16
# without added feat: 15747
# with all added feat: 15916
# finished round 17
# without added feat: 15717
# with all added feat: 15927
# finished round 18
# without added feat: 15750
# with all added feat: 15898
# finished round 19
# without added feat: 15747
# with all added feat: 15922
# finished round 20
# without added feat: 15730
# with all added feat: 15883
# finished round 21
# without added feat: 15755
# with all added feat: 15904
# finished round 22
# without added feat: 15750
# with all added feat: 15901
# finished round 23
# without added feat: 15766
# with all added feat: 15922
# finished round 24
# without added feat: 15771
# with all added feat: 15927
# finished round 25
# running 0.2ng_rep1
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 7066
# with all added feat: 7164
# finished round 1
# without added feat: 7120
# with all added feat: 7190
# finished round 2
# without added feat: 7114
# with all added feat: 7188
# finished round 3
# without added feat: 7119
# with all added feat: 7165
# finished round 4
# without added feat: 7081
# with all added feat: 7188
# finished round 5
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 7030
# with all added feat: 7180
# finished round 6
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 7130
# with all added feat: 7206
# finished round 7
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 7085
# with all added feat: 7106
# finished round 8
# without added feat: 7147
# with all added feat: 7176
# finished round 9
# without added feat: 7112
# with all added feat: 7169
# finished round 10
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 7140
# with all added feat: 7199
# finished round 11
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 7126
# with all added feat: 7152
# finished round 12
# without added feat: 7114
# with all added feat: 7178
# finished round 13
# without added feat: 7046
# with all added feat: 7203
# finished round 14
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 7022
# with all added feat: 7179
# finished round 15
# without added feat: 7011
# with all added feat: 7181
# finished round 16
# without added feat: 7130
# with all added feat: 7171
# finished round 17
# without added feat: 7112
# with all added feat: 7173
# finished round 18
# without added feat: 7137
# with all added feat: 7187
# finished round 19
# without added feat: 7144
# with all added feat: 7175
# finished round 20
# without added feat: 7111
# with all added feat: 7188
# finished round 21
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 7147
# with all added feat: 7173
# finished round 22
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 7036
# with all added feat: 7204
# finished round 23
# without added feat: 7103
# with all added feat: 7201
# finished round 24
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 7093
# with all added feat: 7177
# finished round 25
# running 0.2ng_rep2
# without added feat: 6954
# with all added feat: 7045
# finished round 1
# without added feat: 6896
# with all added feat: 7090
# finished round 2
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 6931
# with all added feat: 7077
# finished round 3
# without added feat: 6944
# with all added feat: 6996
# finished round 4
# without added feat: 7024
# with all added feat: 7007
# finished round 5
# without added feat: 6813
# with all added feat: 7185
# finished round 6
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 6855
# with all added feat: 7040
# finished round 7
# without added feat: 6814
# with all added feat: 6994
# finished round 8
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 6873
# with all added feat: 6946
# finished round 9
# without added feat: 6812
# with all added feat: 7037
# finished round 10
# without added feat: 7046
# with all added feat: 7050
# finished round 11
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 7138
# with all added feat: 6930
# finished round 12
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 7006
# with all added feat: 7187
# finished round 13
# without added feat: 6975
# with all added feat: 7131
# finished round 14
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 7041
# with all added feat: 7085
# finished round 15
# without added feat: 7058
# with all added feat: 7162
# finished round 16
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 7008
# with all added feat: 6810
# finished round 17
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 6815
# with all added feat: 6968
# finished round 18
# without added feat: 6865
# with all added feat: 6949
# finished round 19
# without added feat: 7028
# with all added feat: 7067
# finished round 20
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# ...
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 5112
# with all added feat: 5143
# finished round 25
# running 0.2ng_rep5
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 5514
# with all added feat: 5608
# finished round 1
# without added feat: 5577
# with all added feat: 5583
# finished round 2
# without added feat: 5541
# with all added feat: 5574
# finished round 3
# without added feat: 5567
# with all added feat: 5566
# finished round 4
# without added feat: 5584
# with all added feat: 5573
# finished round 5
# without added feat: 5540
# with all added feat: 5579
# finished round 6
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 5534
# with all added feat: 5588
# finished round 7
# without added feat: 5524
# with all added feat: 5578
# finished round 8
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 5520
# with all added feat: 5580
# finished round 9
# without added feat: 5575
# with all added feat: 5600
# finished round 10
# without added feat: 5552
# with all added feat: 5574
# finished round 11
# without added feat: 5534
# with all added feat: 5533
# finished round 12
# without added feat: 5557
# with all added feat: 5569
# finished round 13
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 5538
# with all added feat: 5586
# finished round 14
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 5530
# with all added feat: 5538
# finished round 15
# without added feat: 5550
# with all added feat: 5581
# finished round 16
# without added feat: 5519
# with all added feat: 5616
# finished round 17
# without added feat: 5563
# with all added feat: 5567
# finished round 18
# without added feat: 5573
# with all added feat: 5595
# finished round 19
# without added feat: 5550
# with all added feat: 5567
# finished round 20
# without added feat: 5559
# with all added feat: 5604
# finished round 21
# without added feat: 5542
# with all added feat: 5590
# finished round 22
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 5582
# with all added feat: 5563
# finished round 23
# without added feat: 5507
# with all added feat: 5589
# finished round 24
# without added feat: 5486
# with all added feat: 5592
# finished round 25
# running 0.2ng_rep6
# without added feat: 5265
# with all added feat: 5290
# finished round 1
# without added feat: 5282
# with all added feat: 5325
# finished round 2
# without added feat: 5266
# with all added feat: 5323
# finished round 3
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 5272
# with all added feat: 5324
# finished round 4
# without added feat: 5291
# with all added feat: 5314
# finished round 5
# without added feat: 5272
# with all added feat: 5335
# finished round 6
# without added feat: 5283
# with all added feat: 5293
# finished round 7
# without added feat: 5273
# with all added feat: 5324
# finished round 8
# without added feat: 5319
# with all added feat: 5306
# finished round 9
# without added feat: 5292
# with all added feat: 5315
# finished round 10
# without added feat: 5285
# with all added feat: 5303
# finished round 11
# without added feat: 5265
# with all added feat: 5327
# finished round 12
# without added feat: 5260
# with all added feat: 5329
# finished round 13
# without added feat: 5279
# with all added feat: 5322
# finished round 14
# without added feat: 5285
# with all added feat: 5323
# finished round 15
# without added feat: 5296
# with all added feat: 5325
# finished round 16
# without added feat: 5281
# with all added feat: 5283
# finished round 17
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 5267
# with all added feat: 5328
# finished round 18
# without added feat: 5285
# with all added feat: 5320
# finished round 19
# without added feat: 5305
# with all added feat: 5301
# finished round 20
# without added feat: 5284
# with all added feat: 5344
# finished round 21
# without added feat: 5223
# with all added feat: 5305
# finished round 22
# without added feat: 5260
# with all added feat: 5318
# finished round 23
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 5269
# with all added feat: 5312
# finished round 24
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# Warning: IRLS did not converge with maxIter = 50
# without added feat: 5293
# with all added feat: 5346
# finished round 25

# %% [markdown]
# Making the graph for the average number of PSMs at or under a 0.01 cutoff. Standard deviation is given as well.

# %%
df = pd.DataFrame(list(zip(no_addedFeats_list, all_features_list)),
               columns =['No Features', 'All Features'])

# %%
def label_diff(x1, x2, pval, column):
  # statistical annotation
    #x1, x2 = 0, 1   # columns 'Sat' and 'Sun' (first column: 0, see plt.xticks())
    y, h, col = all_results[column].max() + 100, 2, 'k'
    plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
    plt.text((x1+x2)*.5, y+h, pval, ha='center', va='bottom', color=col)

# %%
from decimal import Decimal
def calc_pval(col1, col2):
    t_test = stats.ttest_ind(col1, col2)
    #pval = "{:.3f}".format(Decimal(t_test.pvalue))
    pval = '%.2E' % Decimal((t_test.pvalue))
    return pval

# %%
import seaborn as sns

segment = all_results[['2ng_rep1 None', '2ng_rep1 All', '2ng_rep2 None', '2ng_rep2 All',
       '2ng_rep3 None', '2ng_rep3 All', '2ng_rep4 None', '2ng_rep4 All',
       '2ng_rep5 None', '2ng_rep5 All', '2ng_rep6 None', '2ng_rep6 All']]

features_plot = sns.boxplot(data=segment, showfliers=False)
features_plot = sns.stripplot(data=segment, jitter=True, color=".3")
features_plot.set(ylabel = "Number of PSMs per scan")
features_plot.set(xlabel = "Presence of Features")


pval = calc_pval(all_results["2ng_rep1 None"], all_results["2ng_rep1 All"])
label_diff(0,1, pval, "2ng_rep1 All")

pval = calc_pval(all_results["2ng_rep2 None"], all_results["2ng_rep2 All"])
label_diff(2,3, pval, "2ng_rep2 All")

calc_pval(all_results["2ng_rep3 None"], all_results["2ng_rep2 All"])
label_diff(4,5, pval, "2ng_rep3 All")

pval = calc_pval(all_results["2ng_rep4 None"], all_results["2ng_rep4 All"])
label_diff(6,7, pval, "2ng_rep4 All")

pval = calc_pval(all_results["2ng_rep5 None"], all_results["2ng_rep5 All"])
label_diff(8,9, pval, "2ng_rep5 All")

pval = calc_pval(all_results["2ng_rep6 None"], all_results["2ng_rep6 All"])
label_diff(10,11, pval, "2ng_rep6 All")


plt.show()

# %%
import seaborn as sns

point2ng_df = all_results[['0.2ng_rep1 None', '0.2ng_rep1 All', '0.2ng_rep2 None', 
                           '0.2ng_rep2 All', '0.2ng_rep3 None', '0.2ng_rep3 All', 
                           '0.2ng_rep4 None', '0.2ng_rep4 All', '0.2ng_rep5 None', 
                           '0.2ng_rep5 All', '0.2ng_rep6 None', '0.2ng_rep6 All']]
test = all_results[['0.2ng_rep4 None', '0.2ng_rep4 All']]

features_plot = sns.boxplot(data=point2ng_df, showfliers=False)
features_plot = sns.stripplot(data=point2ng_df, jitter=True, color=".3")
features_plot.set(ylabel = "Number of PSMs per scan")
features_plot.set(xlabel = "Presence of Features")


pval = calc_pval(all_results['0.2ng_rep1 None'], all_results['0.2ng_rep1 All'])
label_diff(0,1, pval, "0.2ng_rep1 All")

pval = calc_pval(all_results["0.2ng_rep2 None"], all_results["0.2ng_rep2 All"])
label_diff(2,3, pval, "0.2ng_rep2 All")

calc_pval(all_results["0.2ng_rep3 None"], all_results["0.2ng_rep3 All"])
label_diff(4,5, pval, "0.2ng_rep3 All")

pval = calc_pval(all_results["0.2ng_rep4 None"], all_results["0.2ng_rep4 All"])
label_diff(6,7, pval, "0.2ng_rep4 All")

pval = calc_pval(all_results["0.2ng_rep5 None"], all_results["0.2ng_rep5 All"])
label_diff(8,9, pval, "0.2ng_rep5 All")

pval = calc_pval(all_results["0.2ng_rep6 None"], all_results["0.2ng_rep6 All"])
label_diff(10,11, pval, "0.2ng_rep6 All")


plt.show()

# %%
import seaborn as sns

point2ng_df = all_results[['0.2ng_rep1 None', '0.2ng_rep1 All', '0.2ng_rep2 None', 
                           '0.2ng_rep2 All', '0.2ng_rep3 None', '0.2ng_rep3 All', 
                           '0.2ng_rep4 None', '0.2ng_rep4 All', '0.2ng_rep5 None', 
                           '0.2ng_rep5 All', '0.2ng_rep6 None', '0.2ng_rep6 All']]
test = all_results[['0.2ng_rep4 None', '0.2ng_rep4 All']]

features_plot = sns.boxplot(data=test, showfliers=False)
features_plot = sns.stripplot(data=test, jitter=True, color=".3")
features_plot.set(ylabel = "Number of PSMs per scan")
features_plot.set(xlabel = "Presence of Features")


# pval = calc_pval(all_results['0.2ng_rep1 None'], all_results['0.2ng_rep1 All'])
# label_diff(0,1, pval, "0.2ng_rep1 All")

# pval = calc_pval(all_results["0.2ng_rep2 None"], all_results["0.2ng_rep2 All"])
# label_diff(2,3, pval, "0.2ng_rep2 All")

# calc_pval(all_results["0.2ng_rep3 None"], all_results["0.2ng_rep3 All"])
# label_diff(4,5, pval, "0.2ng_rep3 All")

pval = calc_pval(all_results["0.2ng_rep4 None"], all_results["0.2ng_rep4 All"])
label_diff(6,7, pval, "0.2ng_rep4 All")

# pval = calc_pval(all_results["0.2ng_rep5 None"], all_results["0.2ng_rep5 All"])
# label_diff(8,9, pval, "0.2ng_rep5 All")

# pval = calc_pval(all_results["0.2ng_rep6 None"], all_results["0.2ng_rep6 All"])
# label_diff(10,11, pval, "0.2ng_rep6 All")


plt.show()

# %%
import statistics as stats

avg1 = (stats.mean(all_results['0.2ng_rep1 All']) - stats.mean(all_results['0.2ng_rep1 None']))/stats.mean(all_results['0.2ng_rep1 None'])
avg2 = (stats.mean(all_results['0.2ng_rep2 All']) - stats.mean(all_results['0.2ng_rep2 None']))/stats.mean(all_results['0.2ng_rep2 None'])
avg3 = (stats.mean(all_results['0.2ng_rep3 All']) - stats.mean(all_results['0.2ng_rep3 None']))/stats.mean(all_results['0.2ng_rep3 None'])
avg4 = (stats.mean(all_results['0.2ng_rep4 All']) - stats.mean(all_results['0.2ng_rep4 None']))/stats.mean(all_results['0.2ng_rep4 None'])
avg5 = (stats.mean(all_results['0.2ng_rep5 All']) - stats.mean(all_results['0.2ng_rep5 None']))/stats.mean(all_results['0.2ng_rep5 None'])
avg6 = (stats.mean(all_results['0.2ng_rep6 All']) - stats.mean(all_results['0.2ng_rep6 None']))/stats.mean(all_results['0.2ng_rep6 None'])
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
increases = [avg1*100, avg2*100, avg3*100, avg4*100, avg5*100, avg6*100]
tools = ["0.2ng_rep1", "0.2ng_rep2", "0.2ng_rep3", "0.2ng_rep4", "0.2ng_rep5", "0.2ng_rep6"]
ax.bar(tools, increases)
plt.ylabel('average % increase')
plt.xlabel('0.2ng files')
#plt.xlabel('Number of PSMs using native score and 0.01 cutoff')
plt.title('Average % increase in # PSMs after additional features and MokaPot')
plt.show()

# %%
import statistics as stats

avg1 = stats.mean(all_results['2ng_rep1 All']) - stats.mean(all_results['2ng_rep1 None'])
avg2 = stats.mean(all_results['2ng_rep2 All']) - stats.mean(all_results['2ng_rep2 None'])
avg3 = stats.mean(all_results['2ng_rep3 All']) - stats.mean(all_results['2ng_rep3 None'])
avg4 = stats.mean(all_results['2ng_rep4 All']) - stats.mean(all_results['2ng_rep4 None'])
avg5 = stats.mean(all_results['2ng_rep5 All']) - stats.mean(all_results['2ng_rep5 None'])
avg6 = stats.mean(all_results['2ng_rep6 All']) - stats.mean(all_results['2ng_rep6 None'])
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
increases = [avg1, avg2, avg3, avg4, avg5, avg6]
tools = ["2ng_rep1", "2ng_rep2", "2ng_rep3", "2ng_rep4", "2ng_rep5", "2ng_rep6"]
ax.bar(tools, increases)
plt.ylabel('average increase')
plt.xlabel('2ng files')
#plt.xlabel('Number of PSMs using native score and 0.01 cutoff')
plt.title('Average increase in # PSMs after additional features and MokaPot')
plt.show()
