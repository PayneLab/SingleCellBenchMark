# %% [markdown]
# # MGF

# %%
import matplotlib.pyplot as plt
import spectrum_utils.plot as sup
import spectrum_utils.spectrum as sus
from pyteomics import mgf
# Out:
# RDKit WARNING: [10:08:11] Enabling RDKit 2019.09.3 jupyter extensions

# %%
def plot_spec(my_title, my_peptide):
    # Read the spectrum from an MGF file using Pyteomics.
    spectrum_dict = mgf.get_spectrum(
        '/Users/hannahboekweg/Payne/mgf_files/Ex_Auto_DrM3_30umT4_2ngQC_60m_half.mgf',
        "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.6.6.3 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=6\""
    )

    # Read the spectrum from an MGF file using Pyteomics.
    spectrum_dict = mgf.get_spectrum(
        '/Users/hannahboekweg/Payne/mgf_files/Ex_Auto_DrM3_30umT4_2ngQC_60m_half.mgf',
        my_title
    )

    identifier = spectrum_dict['params']['title']
    precursor_mz = spectrum_dict['params']['pepmass'][0]
    precursor_charge = spectrum_dict['params']['charge'][0]
    mz = spectrum_dict['m/z array']
    intensity = spectrum_dict['intensity array']
    retention_time = float(spectrum_dict['params']['rtinseconds'])
    peptide = my_peptide



    # Create the MS/MS spectrum.
    spectrum = sus.MsmsSpectrum(
        identifier, precursor_mz, precursor_charge, mz, intensity,
        retention_time=retention_time, peptide=peptide)

    # Process the MS/MS spectrum.
    fragment_tol_mass = 20
    fragment_tol_mode = 'ppm'
    spectrum = (spectrum.set_mz_range(min_mz=100, max_mz=1400)
                .remove_precursor_peak(fragment_tol_mass, fragment_tol_mode)
                .filter_intensity(min_intensity=0.05, max_num_peaks=50)
                .scale_intensity('root')
                .annotate_peptide_fragments(fragment_tol_mass, fragment_tol_mode,
                                            ion_types='aby'))

    # Plot the MS/MS spectrum.
    fig, ax = plt.subplots(figsize=(12, 6))
    sup.spectrum(spectrum, ax=ax)
    plt.show()
    plt.close()

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.19990.19990.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=19990\""
my_peptide = 'ALDVSASDDEIAR'
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.19991.19991.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=19991\""
my_peptide = "PGVDEEPQHVLLR"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.19991.19991.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=19991\""
my_peptide = "LDFEGPDAK"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.19992.19992.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=19992\""
my_peptide = "PSPLLVGR"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.19994.19994.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=19994\""
my_peptide = "AVLLGPPGAGK"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.19995.19995.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=19995\""
my_peptide = "HPDYAILAAR"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.19995.19995.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=19995\""
my_peptide = "FYIEGSEPGK"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.19996.19996.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=19996\""
my_peptide = "LVPLNQESVEER"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.19996.19996.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=19996\""
my_peptide = "MEVDYSATVDQR"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.19997.19997.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=19997\""
my_peptide = "EDGPGIPADIK"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.19997.19997.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=19997\""
my_peptide = "GEFTIETEGK"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.19998.19998.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=19998\""
my_peptide = "LLHDLQIGEK"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.19999.19999.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=19999\""
my_peptide = "QFQDAGHFDAENIK"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.20001.20001.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=20001\""
my_peptide = "IDATSASVLASR"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.20003.20003.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=20003\""
my_peptide = "DILETHLR"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.20003.20003.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=20003\""
my_peptide = "GMNYLEDR"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.20004.20004.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=20004\""
my_peptide = "STIIGESISR"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.20005.20005.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=20005\""
my_peptide = "SYSYVCGISSK"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.20006.20006.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=20006\""
my_peptide = "KEPAVLELEGK"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.20007.20007.3 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=20007\""
my_peptide = "TFTTQETITNAETAK"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.20008.20008.3 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=20008\""
my_peptide = "HQAQIDHYLGLANK"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.20009.20009.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=20009\""
my_peptide = "EDGPGIPADIK"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.20009.20009.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=20009\""
my_peptide = "GEFTIETEGK"
plot_spec(my_title, my_peptide)

# %%
my_title = "Ex_Auto_DrM3_30umT4_2ngQC_60m_half.20010.20010.2 File:\"Ex_Auto_DrM3_30umT4_2ngQC_60m_half.raw\", NativeID:\"controllerType=0 controllerNumber=1 scan=20010\""
my_peptide = "LSQLEGVNVER"
plot_spec(my_title, my_peptide)
